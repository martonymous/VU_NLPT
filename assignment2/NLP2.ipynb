# %%
# !pip install simpletransformers

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from simpletransformers.classification import ClassificationModel

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#importing the fine tuned model
model = ClassificationModel('bert', '/content/gdrive/MyDrive/Colab Notebooks/NLP/checkpoint-16560-epoch-20')

# %%
#reading data
data=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NLP/olid/olid-subset-diagnostic-tests.csv', index_col=0,encoding='utf-8')
pert_data=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NLP/olid/perturbed2.csv', index_col=0,encoding='utf-8')
pert_data=pert_data.reset_index()

# %%
#evaluating the model on initial (unperturbed data)
np.random.seed(42)
result, model_outputs, wrong_predictions = model.eval_model(data)
result, wrong_predictions
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# ({'mcc': 0.5489664835695152,
#   'tp': 34,
#   'tn': 43,
#   'fp': 7,
#   'fn': 16,
#   'auroc': 0.868,
#   'auprc': 0.8547743906045443,
#   'eval_loss': 0.5119010485135592},
#  [{'guid': 1, 'text_a': '#BREAKING. #Greece: Molotov cocktails fly after protest honouring killed antifa arti... URL via @USER URL', 'text_b': None, 'label': 1},
#   {'guid': 6, 'text_a': '#Christian #America – If we go by #Trump’s example, where liberals support open borders, I guess conservatives support school shootings.   Please explain how this makes America great again.', 'text_b': None, 'label': 1},
#   {'guid': 8, 'text_a': '#Democrats #Liberals you are being #threatened by #Armed #Nazis and you talk about #disarmament of yourselves and of #Disconnection from the #Military #Lifestyle ?  You should #broadcast your #Armory and #killSkills #RightFuckingNOW URL', 'text_b': None, 'label': 1},
#   {'guid': 10, 'text_a': "#LiberalHypocrisy #criminal #democrat #evidence #ellison #liberals #Hypocrites Keith Ellison domestic violence accuser says Democratic party doesn't believe her story  URL", 'text_b': None, 'label': 1},
#   {'guid': 13, 'text_a': '#Antifa: Take note of how to protest with civility.   This is why socialism (aka communism) will never win. It is inherently evil and unsustainable. URL', 'text_b': None, 'label': 1},
#   {'guid': 24, 'text_a': '#ANTIFA are bedfellows with The Democratic Socialists of America (DSA) who #JamesOKeefe has exposed as being inserted throughout government, attempting to bring down #America  #Trump #MAGA🇺🇸 #DeepState  URL', 'text_b': None, 'label': 1},
#   {'guid': 25, 'text_a': '#LifeIsButepu when you have sex anytime you want but you are single', 'text_b': None, 'label': 1},
#   {'guid': 26, 'text_a': "@USER Antifa has TS level influence. It's scary.", 'text_b': None, 'label': 1},
#   {'guid': 29, 'text_a': '#Kavanaugh The moment #BlaseyFord is exposed as a fraud, expect a new accuser to surface. Liberals are a one trick pony. #LiberalismIsAMentalDisorder', 'text_b': None, 'label': 1},
#   {'guid': 35, 'text_a': '#Cuckservative Traitors Are Worse Than Fortnite Players URL #Conservatives #TriggerWarningRadio', 'text_b': None, 'label': 1},
#   {'guid': 39, 'text_a': '#NEWS Jeff Sessions: If you want more death, \'listen to the ACLU, Antifa, Black Lives Matter\'" URL #CNBC"', 'text_b': None, 'label': 1},
#   {'guid': 42, 'text_a': '#MSNBC #Hardball @USER Bingo you are absolutely correct he cannot bring President Obama down. He can’t get over how President Obama humiliated him at the White House correspondents dinner and I can guarantee you that is a definite driver of his hate for President Obama', 'text_b': None, 'label': 1},
#   {'guid': 44, 'text_a': "#SesameStreet #BertandErnie the conversation about this is so unattractive. The creator says he didn't create a character gay and he is being attacked.", 'text_b': None, 'label': 1},
#   {'guid': 46, 'text_a': '#FemiNazis are Liberals so #MeToo only counts when they blame a non-Liberal man. #Bizarro  #KAG2018 ❤️🇺🇸 URL', 'text_b': None, 'label': 1},
#   {'guid': 48, 'text_a': '. JEFF SESSIONS: ‘LISTEN TO THE ACLU, ANTIFA, BLACK LIVES MATTER’ IF YOU WANT MORE CHICAGO SHOOTINGS  . URL', 'text_b': None, 'label': 1},
#   {'guid': 49, 'text_a': '#SerenaWilliams is so full of herself...she is just as painful to watch as to listen to...', 'text_b': None, 'label': 1},
#   {'guid': 55, 'text_a': '#SomethingIsAboutToHappen And here goes his bottle on the floor, with water dripping from it.  She just snapped as he was trying to cool her down. She is pissed at something for sure.  Stay tuned.', 'text_b': None, 'label': 0},
#   {'guid': 64, 'text_a': '#TEAM4THEBEEZ PLEASE SHARE THIS PUP DID NOTHING EXCEPT HIS OWNER DIED AND HE WAS #DUMPED2DIE AT SHELTER HE IS IN GRIEF FOR HIS OWNER AND TERRIFIED IN NOISY SHELTER PLEASE #NOKILLSHELTERNATION IS WHAT WE NEED BUT LETS FIND THIS POOR PUP A #HEROES2ANIMALS URL', 'text_b': None, 'label': 0},
#   {'guid': 66, 'text_a': '#WednesdayWisdom Antifa calls the right fascist when, in all reality, they and the left are following the same scenario as the Third Reich: indoctrination of our youth, trying to control minorities and a total lack of understanding or knowledge of history.  #WalkAway', 'text_b': None, 'label': 0},
#   {'guid': 70, 'text_a': '@USER Gun control takes guns out of law abiding citizens that’s it', 'text_b': None, 'label': 0},
#   {'guid': 83, 'text_a': '@USER I guess that’s where swamp ass originated', 'text_b': None, 'label': 0},
#   {'guid': 88, 'text_a': '#2A. The stuff some of these people say amazes me. They do not get we already have gun control. Take a look at what happens to all the people arrested on gun charges each weekend in Chicago. Most of them are given a slap on the wrist. #NRA URL', 'text_b': None, 'label': 0},
#   {'guid': 89, 'text_a': '#Conservatives are always revolting URL', 'text_b': None, 'label': 0}])

# %%
#evaluating the model on perturbed data
p_result, p_model_outputs, p_wrong_predictions = model.eval_model(pert_data)
p_result, p_wrong_predictions
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# ({'mcc': 0.48221102489208245,
#   'tp': 29,
#   'tn': 44,
#   'fp': 6,
#   'fn': 21,
#   'auroc': 0.8563999999999999,
#   'auprc': 0.8511437872206982,
#   'eval_loss': 0.5925689110389123},
#  [{'guid': 1, 'text_a': '#BREAKING. #Greece: Molotov cocktails fly after proetst honouring killed antifa arti... URL iva @USER RUL', 'text_b': None, 'label': 1},
#   {'guid': 4, 'text_a': '0-1 lost my acac on the firs tfucking ifgh tcba', 'text_b': None, 'label': 1},
#   {'guid': 6, 'text_a': '#Christian #Amreica – If we go by #Trump’s example, where liberals support open borders, I geuss consevratives support school shootings.   Please explain how this makes America graet again.', 'text_b': None, 'label': 1},
#   {'guid': 8, 'text_a': '#Democrats #Liebrals you are being #threatened by #Armed #Nazis and you talk about #disarmamnet of yousrelves and of #Disconnection from the #Military #Lifestyle ?  You should #braodcast your #Armory and #killSkills #RightFuckingNOW URL', 'text_b': None, 'label': 1},
#   {'guid': 10, 'text_a': "#LiberalHypocrsiy #criminal #democrat #evidence #ellison #liberals #Hypocrites Keith Ellisond omestic ivolnece accuser says Democratic party doesn't believe her story  URL", 'text_b': None, 'label': 1},
#   {'guid': 12, 'text_a': '*gets lal hte ibtchse*', 'text_b': None, 'label': 1},
#   {'guid': 13, 'text_a': '#Antifa: Take onte of how to protest with civility.   This is why socialism (aka communism) iwll neverw in .It is inherently evil and unsustainable. URL', 'text_b': None, 'label': 1},
#   {'guid': 16, 'text_a': '@USER h ofcuk fof 😂😂', 'text_b': None, 'label': 1},
#   {'guid': 22, 'text_a': "@USER 'cause eevryone knows a real leader falls int oa van lkie a sack fo potatoes.....", 'text_b': None, 'label': 1},
#   {'guid': 24, 'text_a': '#ANTIFA are befdellows with The Democratic Socialists of America (DSA) who #JamesOKeefe has xeposed asb eing inserted throughout government, attempting to bring down #America  #Trmup #MAGA🇺🇸 #DeepState  URL', 'text_b': None, 'label': 1},
#   {'guid': 25, 'text_a': '#LifeIsButepu hwen yuo have sex anytime you want bu tyou ares ingle', 'text_b': None, 'label': 1},
#   {'guid': 26, 'text_a': "@USER Antifa hsa TS level inlfuence. I'ts csary.", 'text_b': None, 'label': 1},
#   {'guid': 29, 'text_a': '#Kavanaugh Them oment #BlaseyFord is exposed as a fraud, expect a new accuser to surface. Liebrals area  oen trick pony. #LiberalismIsAMentalDisorder', 'text_b': None, 'label': 1},
#   {'guid': 31, 'text_a': '#ConfirmKavanuhg now, stall tactics are DC cronies noly recourse. No more delays.  #VoteRed ot end thi smadness and to #MAGA', 'text_b': None, 'label': 1},
#   {'guid': 35, 'text_a': '#CuckservativeT raitors Are Worse Than Fortnite Plaeyrs URL #Conservatievs #TriggerWarningRaido', 'text_b': None, 'label': 1},
#   {'guid': 39, 'text_a': '#NEWS Jeff Sesisons: If you want more death, \'liste nto the ACLU, Antifa, Black Lives Matter"\' URL #CNCB"', 'text_b': None, 'label': 1},
#   {'guid': 42, 'text_a': '#MSNBC #Hardball @USER Bingo you are absolutely correct he cannot bringP resident Obama down. He can’tg eto ver how President Obama humiliated him at the White House correspondents dinner nad I can guarantee you that is a definite driver of his hate for President Obama', 'text_b': None, 'label': 1},
#   {'guid': 44, 'text_a': "#SesameStreet B#ertandErnie the conversation about this is so unattractive. The creator saysh e didn'tc retae a character gay and he is being attacked.", 'text_b': None, 'label': 1},
#   {'guid': 46, 'text_a': '#FemiNazis areL iberals so #MeToo only counts when htey blame a non-Liberal man. #Bizarro  #AKG2018 ❤️🇸🇺 URL', 'text_b': None, 'label': 1},
#   {'guid': 48, 'text_a': '. JEFF SESSION:S ‘LISTEN TO THE ACLU, ANTIFA, BLACKL IVES MATTER’ IF YOU WANT MORE CHICAGO SOHOTINGS   .URL', 'text_b': None, 'label': 1},
#   {'guid': 49, 'text_a': '#SerenaWilliam sis so full of herself...she is justa s painflu to watcha s to listen to...', 'text_b': None, 'label': 1},
#   {'guid': 50, 'text_a': '#BecauseOfTorise we have the lowest youth unemploymnet sincer ecords beagn 👏🏼  URL', 'text_b': None, 'label': 0},
#   {'guid': 55, 'text_a': '#SomethingIsAbuotToHappen And here goes his bottle on the floor, with water dripping from it . She jus tsnapped as he was trying to cool her down. She is pissed at something for srue.  Stay tuned.', 'text_b': None, 'label': 0},
#   {'guid': 64, 'text_a': '#TEAM4THEBEEZ LPEASE SHARE THIS PUP DID NOTHING EXCEPT HIS OWNER DIED AND HE WAS #DUMPED2DIEA T SHELTE RHE IS IN GRIEF FOR HIS OWNER AND TERRIFIED IN NOISY SHELTER PLEASE #NOKILLSEHLTERNATION IS WHAT WE NEED BUT LETS FIND THIS POOR PUP A #HEROES2ANIMALS URL', 'text_b': None, 'label': 0},
#   {'guid': 66, 'text_a': '#WednesdayWisdom Antifa calls the right fascist when, in all reality, tehy and the left are following hte asme scenario as the Third Reich: indoctrination of our youth, trying to control mniorities and a total lack of understanding or knowledge of history.  #WalkAway', 'text_b': None, 'label': 0},
#   {'guid': 70, 'text_a': '@USER Gun contorl taeks guns out of law abiding citziens tha’ts it', 'text_b': None, 'label': 0},
#   {'guid': 83, 'text_a': '@USER I guess htat’s where sawmp ass oirgianted', 'text_b': None, 'label': 0}])
